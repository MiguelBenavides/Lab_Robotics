# %% [markdown]
# ## Universidad de Monterrey
# Engineering Division
# Laboratory of Advanced Robotics
#
# ### Lab 5: Blending images and measuring code performance
# Authors: Laura Morales, Miguel Benavides
#
# ### Introduction
#
# The following practice consists on analyzing images in order to get their properties such as number of channels and image resolution, we will also work with retrieving intensity values of pixels, setting a region of interest, blending images, performing bitwise operations, and measuring the performance of your code. This report will be divided in three different codes. The first one consists, on adding images, the second one is about blending images, and the third one is about analyzing the code performance. More specific detalis about each code will be provided below.
#
#
# ### Procedure
#
# For this practice, the following tools were required:
#
# * Raspberry Pi with WiFi connection capabilities
# * Jupyter Notebook
# * Python >= 3.5.2
# * OpenCV 3.2
# * Git
# * GitHub account
# * Markdown editor (recommended: ReText 5.3.1)
#
# The base codes for each part of the practice were provided by the instructor but the authors of this report also contributed to the program in order to accomplish the desired objective.
#
#
# ### Adding images
#
# This program consists on the addition or overlay of two images. The objective of this program is to use both possible methods to accomplish this superimposition and compare them to see if there are any differences. Firstable we need to import both images (a validation of this process was added so that the program wouldn't run unless it had an image), then both images were converted to RGB using a method previously learned, and finally, both images were added by the `add()` method from the cv2 library, and the `+` from the numpy library, both of the original images and the superimposed ones were displayed to show the results.

# %%
"""
	add_images.py
	
	This codes lets you superimpose two images using the + operation 
	from the numpy library and the add() method from the cv2 library.
	author: Miguel Benavides 
	date created: 3 May 2018
	universidad de monterrey
"""

# import required libraries
import numpy as np
import matplotlib.pyplot as plt
import cv2

# specify names of image files
image_name_1 = 'salinas_beach_queijo_asado.jpg'
image_name_2 = 'salinas_beach_bird.jpg'

# load image 1
img_1 = cv2.imread(image_name_1, cv2.IMREAD_COLOR)

# verify that img_1 exists
if img_1 is None:
	print('ERROR: image ', image_name_1, 'could not be read')
	exit()

# convert BGR to RGB
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

# load image 2
img_2 = cv2.imread(image_name_2, cv2.IMREAD_COLOR)

# verify that img_1 exists
if img_2 is None:
	print('ERROR: image ', image_name_2, 'could not be read')
	exit()

# convert BGR to RGB
img_2 = cv2.cvtColor(img_2, cv2.COLOR_BGR2RGB)

# add images using cv2.add()
img_cv2 = cv2.add(img_1, img_2)

# add images using numpy library
img_np = np.uint8(img_1) + np.uint8(img_2)

# visualise images
plt.figure(1)
plt.imshow(img_1)
plt.title('Image 1')

plt.figure(2)
plt.imshow(img_2)
plt.title('Image 2')

plt.figure(3)
plt.imshow(img_cv2)
plt.title('Sum of Image 1 and Image 2 using cv2.add()')

plt.figure(4)
plt.imshow(img_np)
plt.title('Sum of Image 1 and Image 2 using numpy')

# display figures
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-d66c3e8d735d> in <module>()
#      12 import numpy as np
#      13 import matplotlib.pyplot as plt
# ---> 14 import cv2
#      15
#      16 # specify names of image files
#
# ModuleNotFoundError: No module named 'cv2'

# %% [markdown]
# ### Blending images
#
# In this program we tried an alternative way to overlay images using an equation implemented by the method `cv.addWeighted()` from the OpenCV library. The equation used was the following: ![image.png](attachment:image.png)
# The resulting image of this code was very similar to the ones obtained by the previous methods, except that with this code, you can vary the parameters of the equation to directly affect the image.

# %%
"""
	blend_images.py
	
	This code lets you blend two images instead of adding them, 
	trough an equation img = a * img1 + b* img2 + c, 
	using cv.addWeighted().
	author: Miguel Benavides 
	date created: 3 Marz 2018
	universidad de monterrey
"""

# import required libraries
import numpy as numpy
import matplotlib.pyplot as plt
import cv2

# specify names of image files
image_name_1 = 'salinas_beach_queijo_asado.jpg'
image_name_2 = 'salinas_beach_bird.jpg'

# load image 1
img_1 = cv2.imread(image_name_1, cv2.IMREAD_COLOR)

# verify that img_1 exists
if img_1 is None:
	print('ERROR: image ', image_name_1, 'could not be read')
	exit()

# convert BGR to RGB
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

# load image 2
img_2 = cv2.imread(image_name_2, cv2.IMREAD_COLOR)

# verify that img_1 exists
if img_2 is None:
	print('ERROR: image ', image_name_2, 'could not be read')
	exit()

# convert BGR to RGB
img_2 = cv2.cvtColor(img_2, cv2.COLOR_BGR2RGB)

# blend images
img_blended = cv2.addWeighted(img_1, 0.3, img_2, 0.7, 0)

# visualise images
plt.figure(1)
plt.imshow(img_1)
plt.title('Image 1')

plt.figure(2)
plt.imshow(img_2)
plt.title('Image 2')

plt.figure(3)
plt.imshow(img_blended)
plt.title('Image blended using Image 1 and Image 2')

# display figures
plt.show()

# %% [markdown]
# ### Code Performance Measurement
#
# This program is useful in order to know the performance of the code that you're working with; specially when it comes to large operations, it is handy to manage the processing time. To accomplish this, the OpenCV library offers two methods: `getTickCount()` and `getTickFrecuency`.  The first method returns the number of clock-cycles that have elapsed after a reference event to the moment this method is called, the second method outputs the number of clock-cycles per second so that if you are interested in measuring the execution time that a section of code takes to be completed.

# %%
"""
	measure_code_performance.py
	
	The code below shows you how to measure the performance of 
	the code used for image properties printing and image 
	visualisation in Lab 4.
	author: Miguel Benavides 
	date created: 3 Marz 2018
	universidad de monterrey
"""

# import required libraries
import numpy as numpy
import matplotlib.pyplot as plt
import cv2

# print image statistics
def print_image_statistics(img, head_string):

	"""
		This function generates the statistics for a given 
		image and plots the figure
	"""
	# add your code below this line
	
	# get image size
	img_size = img.shape

	# print image size
	print('\nCOLOUR IMAGE STATS:')
	print('colour image size: ', img_size)

	# retrieve image width resolution
	print('image width resolution: ', img_size[0])

	# retrieve image height resolution
	print('image height resolution: ', img_size[1])

	# retrieve number of channels
	if len(img_size) < 3:
		print('number of channels: ', 1)
	else:
		print('number of channels: ', img_size[2])

	# minimum pixel value in image
	print('minimum intensity value: ', img.min())

	# minimum pixel value in image
	print('max intensity value: ', img.max())

	# maximum intensity value in image
	print('meam intensity value: ', img.mean())

	# print type of image
	print('type of image: ', img.dtype)
	
	return None

# visualise image
def visualise_image(img, fig_number, fig_title, iscolour):

	"""
		This code lets you visualize the image generated
	"""
	# add your code below this line

	# visualise colour image
	plt.figure(fig_number)
	if iscolour == 0:
		plt.imshow(img, cmap='gray')
	else:
		plt.imshow(img)
	plt.title(fig_title)
	plt.xlabel('x-resolution')
	plt.ylabel('y-resolution')
	
	return None

# read image
image_name = 'vehicular_traffic.jpg'
img_colour = cv2.imread(image_name, cv2.IMREAD_COLOR)

# verify that image exists
if img_colour is None:
	print('ERROR: image ', image_name, 'could not be read')
	exit()

# convert from BGR to RGB so that the image can be visualised using matplotlib
img_colour = cv2.cvtColor(img_colour, cv2.COLOR_BGR2RGB)

# convert the input colour image into a grayscale image
e1 = cv2.getTickCount()
img_greyscale = cv2.cvtColor(img_colour, cv2.COLOR_BGR2GRAY)
e2 = cv2.getTickCount()
time = (e2 - e1)/ cv2.getTickFrequency()
print('\nConversion from colour to greyscale took: ', time, 'seconds')

# print colour image stats and visualise it
e1 = cv2.getTickCount()
print_image_statistics(img_colour, 'COLOUR IMAGE STATS:')
e2 = cv2.getTickCount()
time = (e2 - e1)/ cv2.getTickFrequency()
print('\nCODE PERFORMANCE:')
print('printing colour image stats took: ', time, 'seconds')

e1 = cv2.getTickCount()
visualise_image(img_colour, 1, 'INPUT IMAGE: COLOUR', 1)
e2 = cv2.getTickCount()
time = (e2 - e1)/ cv2.getTickFrequency()
print('visualising colour image took: ', time, 'seconds')

# print greyscale image stats and visualise it
e1 = cv2.getTickCount()
print_image_statistics(img_greyscale, 'GREYSCALE IMAGE STATS:')
e2 = cv2.getTickCount()
time = (e2 - e1)/ cv2.getTickFrequency()
print('\nCODE PERFORMANCE:')
print('Printing greyscale image stats took: ', time, 'seconds')

e1 = cv2.getTickCount()
visualise_image(img_greyscale, 2, 'OUTPUT IMAGE: GREYSCALE', 0)
e2 = cv2.getTickCount()
time = (e2 - e1)/ cv2.getTickFrequency()
print('Visualising grey colour image took: ', time, 'seconds')

# visualise figures
plt.show()
# Out:
# /home/lauramaguilera/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:281: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-98c0e353b98d> in <module>()
#      13 import numpy as numpy
#      14 import matplotlib.pyplot as plt
# ---> 15 import cv2
#      16
#      17 # print image statistics
#
# ModuleNotFoundError: No module named 'cv2'

# %% [markdown]
# ### Conclusions
#
# This practice was useful to learn the different methods to overlay an image, which is something very popular this day, there are a lot of apps that use filters that are basically overlapping colors into an image, a well as editing its parameters. The third code is useful to processing time requirements when working with large programs.
